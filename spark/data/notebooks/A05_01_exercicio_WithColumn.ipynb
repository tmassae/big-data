# %% [markdown]
# Autor: Tatiana Massae Sakata

# %% [markdown]
# #  Módulo Spark

# %% [markdown]
# ## <a name="inicio"> Exercicios Aula 5 - WithColumn Parte I</a>

# %% [markdown]
# * [Inicio - Parte 1](#inicio)
# * [Questão 01](#questao01)
# * [Questão 02](#questao02)
# * [Questão 03](#questao03)
# * [Questão 04](#questao04)
# * [Questão 05](#questao05)
# * [Questão 06](#questao06)
#
# <a></a>
# * [Inicio - Parte 2](#iniciop2)
# * [Questão 01](#questao201)
# * [Questão 02](#questao202)
# * [Questão 03](#questao203)

# %% [markdown]
# ### <a name="questao01"> Questão 1. Criar um dataframe para ler o arquivo no HDFS /user/<nome/data/juros_selic/juros_selic </a>
#
# [voltar ao ínicio](#inicio)

# %%
# !hdfs dfs -ls /user/tatiana/data/juros_selic/juros_selic
# Out:
# -rw-r--r--   3 root supergroup       8348 2022-11-10 13:18 /user/tatiana/data/juros_selic/juros_selic

# %%
# !hdfs dfs -cat /user/tatiana/data/juros_selic/juros_selic
# Out:
# "data";"valor"
# "01/06/1986";"1,27"
# "01/07/1986";"1,95"
# "01/08/1986";"2,57"
# "01/09/1986";"2,94"
# "01/10/1986";"1,96"
# "01/11/1986";"2,37"
# "01/12/1986";"5,47"
# "01/01/1987";"11,00"
# "01/02/1987";"19,61"
# "01/03/1987";"11,95"
# "01/04/1987";"15,30"
# "01/05/1987";"24,63"
# "01/06/1987";"18,02"
# "01/07/1987";"8,91"
# "01/08/1987";"8,09"
# "01/09/1987";"7,99"
# "01/10/1987";"9,45"
# "01/11/1987";"12,92"
# "01/12/1987";"14,38"
# "01/01/1988";"16,78"
# "01/02/1988";"18,35"
# "01/03/1988";"16,59"
# "01/04/1988";"20,25"
# "01/05/1988";"18,65"
# "01/06/1988";"20,17"
# "01/07/1988";"24,69"
# "01/08/1988";"22,63"
# "01/09/1988";"26,25"
# "01/10/1988";"29,79"
# "01/11/1988";"28,41"
# "01/12/1988";"30,24"
# "01/01/1989";"22,97"
# "01/02/1989";"18,95"
# "01/03/1989";"20,41"
# "01/04/1989";"11,52"
# "01/05/1989";"11,43"
# "01/06/1989";"27,29"
# "01/07/1989";"33,15"
# "01/08/1989";"35,49"
# "01/09/1989";"38,58"
# "01/10/1989";"47,70"
# "01/11/1989";"48,41"
# "01/12/1989";"64,21"
# ...

# %%
from pyspark.sql.functions import *

juros = spark.read.csv("/user/tatiana/data/juros_selic/juros_selic", sep=";", header="true")

juros.show(5)
# Out:
# +----------+-----+
# |      data|valor|
# +----------+-----+
# |01/06/1986| 1,27|
# |01/07/1986| 1,95|
# |01/08/1986| 2,57|
# |01/09/1986| 2,94|
# |01/10/1986| 1,96|
# +----------+-----+
# only showing top 5 rows

# %% [markdown]
# ###  <a name="questao02"> Questão 2. Alterar o formato do campo data para “MM/dd/yyyy” </a>
#
# [voltar ao ínicio](#inicio)

# %%
juros_americano_unix = juros.withColumn("data", unix_timestamp(col("data"), "dd/MM/yyyy"))

#https://stackoverflow.com/questions/69148721/attributeerror-nonetype-object-has-no-attribute-select-pyspark
#Adicionar o .show(5)no final altera o tipo do objeto de um pyspark DataFrame para NoneType.
juros_americano_unix.show(5)
# Out:
# +---------+-----+
# |     data|valor|
# +---------+-----+
# |517968000| 1,27|
# |520560000| 1,95|
# |523238400| 2,57|
# |525916800| 2,94|
# |528508800| 1,96|
# |531187200| 2,37|
# |533779200| 5,47|
# |536457600|11,00|
# |539136000|19,61|
# |541555200|11,95|
# |544233600|15,30|
# |546825600|24,63|
# |549504000|18,02|
# |552096000| 8,91|
# |554774400| 8,09|
# |557452800| 7,99|
# |560044800| 9,45|
# |562723200|12,92|
# |565315200|14,38|
# |567993600|16,78|
# +---------+-----+
# only showing top 20 rows

# %%
juros_americano = juros_americano_unix.withColumn("data", from_unixtime("data", "MM/dd/yyyy"))
juros_americano.show(5)
# Out:
# +----------+-----+
# |      data|valor|
# +----------+-----+
# |06/01/1986| 1,27|
# |07/01/1986| 1,95|
# |08/01/1986| 2,57|
# |09/01/1986| 2,94|
# |10/01/1986| 1,96|
# |11/01/1986| 2,37|
# |12/01/1986| 5,47|
# |01/01/1987|11,00|
# |02/01/1987|19,61|
# |03/01/1987|11,95|
# |04/01/1987|15,30|
# |05/01/1987|24,63|
# |06/01/1987|18,02|
# |07/01/1987| 8,91|
# |08/01/1987| 8,09|
# |09/01/1987| 7,99|
# |10/01/1987| 9,45|
# |11/01/1987|12,92|
# |12/01/1987|14,38|
# |01/01/1988|16,78|
# +----------+-----+
# only showing top 20 rows

# %%
#mesmo resultado que as duas linhas anteriores em uma unica linha

juros_americano = juros.withColumn("data", from_unixtime(unix_timestamp(col("data"), "dd/MM/yyyy"), "MM/dd/yyyy"))
juros_americano.show(5)
# Out:
# +----------+-----+
# |      data|valor|
# +----------+-----+
# |06/01/1986| 1,27|
# |07/01/1986| 1,95|
# |08/01/1986| 2,57|
# |09/01/1986| 2,94|
# |10/01/1986| 1,96|
# |11/01/1986| 2,37|
# |12/01/1986| 5,47|
# |01/01/1987|11,00|
# |02/01/1987|19,61|
# |03/01/1987|11,95|
# |04/01/1987|15,30|
# |05/01/1987|24,63|
# |06/01/1987|18,02|
# |07/01/1987| 8,91|
# |08/01/1987| 8,09|
# |09/01/1987| 7,99|
# |10/01/1987| 9,45|
# |11/01/1987|12,92|
# |12/01/1987|14,38|
# |01/01/1988|16,78|
# +----------+-----+
# only showing top 20 rows

# %% [markdown]
# ###  <a name="questao03"> Questão 3. Com uso da função from_unixtime crie o campo “ano_unix”, com a informação do ano do campo data </a>
#
# [voltar ao ínicio](#inicio)

# %%
juros_unixtime = juros_americano.withColumn("ano_unix", from_unixtime(unix_timestamp(col("data"), "dd/MM/yyyy"), "yyyy"))
juros_unixtime.show(5)
# Out:
# +----------+-----+--------+
# |      data|valor|ano_unix|
# +----------+-----+--------+
# |06/01/1986| 1,27|    1986|
# |07/01/1986| 1,95|    1986|
# |08/01/1986| 2,57|    1986|
# |09/01/1986| 2,94|    1986|
# |10/01/1986| 1,96|    1986|
# +----------+-----+--------+
# only showing top 5 rows

# %% [markdown]
# ###  <a name="questao04"> Questão 4. Com uso de substring crie o campo “ano_str”, com a informação do ano do campo data </a>
#
# [voltar ao ínicio](#inicio)

# %%
juros_substring = juros_unixtime.withColumn("ano_str", substring(col("data"),7,4))
juros_substring.show(5)
# Out:
# +----------+-----+--------+-------+
# |      data|valor|ano_unix|ano_str|
# +----------+-----+--------+-------+
# |06/01/1986| 1,27|    1986|   1986|
# |07/01/1986| 1,95|    1986|   1986|
# |08/01/1986| 2,57|    1986|   1986|
# |09/01/1986| 2,94|    1986|   1986|
# |10/01/1986| 1,96|    1986|   1986|
# +----------+-----+--------+-------+
# only showing top 5 rows

# %% [markdown]
# ###  <a name="questao05"> Questão 5. Com uso da função split crie o campo “ano_str”, com a informação do ano do campo data </a>
#
# [voltar ao ínicio](#inicio)

# %%
juros_split = juros_substring.withColumn("ano_split", split(col("data"),"/"))
juros_split.show(5)
# Out:
# +----------+-----+--------+-------+--------------+
# |      data|valor|ano_unix|ano_str|     ano_split|
# +----------+-----+--------+-------+--------------+
# |06/01/1986| 1,27|    1986|   1986|[06, 01, 1986]|
# |07/01/1986| 1,95|    1986|   1986|[07, 01, 1986]|
# |08/01/1986| 2,57|    1986|   1986|[08, 01, 1986]|
# |09/01/1986| 2,94|    1986|   1986|[09, 01, 1986]|
# |10/01/1986| 1,96|    1986|   1986|[10, 01, 1986]|
# +----------+-----+--------+-------+--------------+
# only showing top 5 rows

# %%
juros_split = juros_substring.withColumn("ano_split", split(col("data"),"/").getItem(2))
juros_split.show(5)
# Out:
# +----------+-----+--------+-------+---------+
# |      data|valor|ano_unix|ano_str|ano_split|
# +----------+-----+--------+-------+---------+
# |06/01/1986| 1,27|    1986|   1986|     1986|
# |07/01/1986| 1,95|    1986|   1986|     1986|
# |08/01/1986| 2,57|    1986|   1986|     1986|
# |09/01/1986| 2,94|    1986|   1986|     1986|
# |10/01/1986| 1,96|    1986|   1986|     1986|
# +----------+-----+--------+-------+---------+
# only showing top 5 rows

# %% [markdown]
# ###  <a name="questao06"> Questão 6. Salvar no hdfs /user/<seu_nome>/juros_selic_americano no formato CSV, incluindo o cabeçalho </a>
#
# [voltar ao ínicio](#inicio)

# %%
juros_split.write.csv("/user/tatiana/juros_selic", header="true")
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#
# /opt/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#
# Py4JJavaError: An error occurred while calling o87.csv.
# : org.apache.spark.sql.AnalysisException: path hdfs://namenode:8020/user/tatiana/juros_selic already exists.;
# 	at org.apache.spark.sql.execution.datasources.InsertIntoHadoopFsRelationCommand.run(InsertIntoHadoopFsRelationCommand.scala:114)
# ...

# %%
# !hdfs dfs -ls /user/tatiana/juros_selic/
# Out:
# Found 2 items
# -rw-r--r--   2 root supergroup          0 2022-11-15 18:01 /user/tatiana/juros_selic/_SUCCESS
# -rw-r--r--   2 root supergroup      13086 2022-11-15 18:01 /user/tatiana/juros_selic/part-00000-2753cbf9-9f19-4d45-872d-c1c21666fcb7-c000.csv

# %%
# !hdfs dfs -cat /user/tatiana/juros_selic/part-00000-2753cbf9-9f19-4d45-872d-c1c21666fcb7-c000.csv
# Out:
# data,valor,ano_unix,ano_str,ano_split
# 06/01/1986,"1,27",1986,1986,1986
# 07/01/1986,"1,95",1986,1986,1986
# 08/01/1986,"2,57",1986,1986,1986
# 09/01/1986,"2,94",1986,1986,1986
# 10/01/1986,"1,96",1986,1986,1986
# 11/01/1986,"2,37",1986,1986,1986
# 12/01/1986,"5,47",1986,1986,1986
# 01/01/1987,"11,00",1987,1987,1987
# 02/01/1987,"19,61",1987,1987,1987
# 03/01/1987,"11,95",1987,1987,1987
# 04/01/1987,"15,30",1987,1987,1987
# 05/01/1987,"24,63",1987,1987,1987
# 06/01/1987,"18,02",1987,1987,1987
# 07/01/1987,"8,91",1987,1987,1987
# 08/01/1987,"8,09",1987,1987,1987
# 09/01/1987,"7,99",1987,1987,1987
# 10/01/1987,"9,45",1987,1987,1987
# 11/01/1987,"12,92",1987,1987,1987
# 12/01/1987,"14,38",1987,1987,1987
# 01/01/1988,"16,78",1988,1988,1988
# 02/01/1988,"18,35",1988,1988,1988
# 03/01/1988,"16,59",1988,1988,1988
# 04/01/1988,"20,25",1988,1988,1988
# 05/01/1988,"18,65",1988,1988,1988
# 06/01/1988,"20,17",1988,1988,1988
# 07/01/1988,"24,69",1988,1988,1988
# ...

# %% [markdown]
# ## <a name="iniciop2"> Exercicios Aula 5 - WithColumn Parte II</a>

# %% [markdown]
# ### <a name="questao201"> Questão 1. Criar um dataframe para ler o arquivo no HDFS /user/<nome/data/juros_selic/juros_selic </a>
#
# [voltar ao ínicio](#inicio)

# %%
# !hdfs dfs -ls /user/tatiana/data/juros_selic/juros_selic
# Out:
# -rw-r--r--   3 root supergroup       8348 2022-11-10 13:18 /user/tatiana/data/juros_selic/juros_selic

# %%
juros_selic = spark.read.csv("/user/tatiana/data/juros_selic/juros_selic", sep=";", header="true")

juros.show(5)
# Out:
# +----------+-----+
# |      data|valor|
# +----------+-----+
# |01/06/1986| 1,27|
# |01/07/1986| 1,95|
# |01/08/1986| 2,57|
# |01/09/1986| 2,94|
# |01/10/1986| 1,96|
# +----------+-----+
# only showing top 5 rows

# %% [markdown]
# ### <a name="questao202"> Questão 2. Agrupar todas as datas pelo ano em ordem decrescente e salvar a quantidade de meses ocorridos, o valor médio, mínimo e máximo do campo valor com a seguinte estrutura: </a>
#
# [voltar ao ínicio](#inicio)

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *


juros_ano = juros_selic.withColumn("ano", split(col("data"),"/").getItem(2))

# %%
juros_ano = juros_selic.withColumn("ano", split(col("data"),"/").getItem(2))
juros_ano.show(5)
# Out:
# +----------+-----+----+
# |      data|valor| ano|
# +----------+-----+----+
# |01/06/1986| 1,27|1986|
# |01/07/1986| 1,95|1986|
# |01/08/1986| 2,57|1986|
# |01/09/1986| 2,94|1986|
# |01/10/1986| 1,96|1986|
# +----------+-----+----+
# only showing top 5 rows

# %%
juros_valor = juros_ano.withColumn("valor", regexp_replace(col("valor"),"\,","\.").cast(FloatType()))
juros_valor.show(5)
# Out:
# +----------+-----+----+
# |      data|valor| ano|
# +----------+-----+----+
# |01/06/1986| 1.27|1986|
# |01/07/1986| 1.95|1986|
# |01/08/1986| 2.57|1986|
# |01/09/1986| 2.94|1986|
# |01/10/1986| 1.96|1986|
# +----------+-----+----+
# only showing top 5 rows

# %%
juros_valor.printSchema()
# Out:
# root
#  |-- data: string (nullable = true)
#  |-- valor: float (nullable = true)
#  |-- ano: string (nullable = true)

# %%
juros_relatorio = juros_valor.groupBy("ano").count().show(5)
# Out:
# +----+-----+
# | ano|count|
# +----+-----+
# |1987|   12|
# |2016|   12|
# |2012|   12|
# |1988|   12|
# |2019|    2|
# +----+-----+
# only showing top 5 rows

# %%
juros_relatorio = juros_valor.groupBy("ano").agg(count("ano").alias("Meses"), 
                                                 format_number(avg("valor"),2).alias("Valor médio"), 
                                                 min("valor").alias("Valor minimo"), 
                                                 max("valor").alias("Valor maximo")).sort(desc("ano"))
juros_relatorio.show(5)
# Out:
# +----+-----+-----------+------------+------------+
# | ano|Meses|Valor médio|Valor minimo|Valor maximo|
# +----+-----+-----------+------------+------------+
# |2019|    2|       0.46|        0.37|        0.54|
# |2018|   12|       0.52|        0.47|        0.58|
# |2017|   12|       0.79|        0.54|        1.09|
# |2016|   12|       1.10|         1.0|        1.22|
# |2015|   12|       1.04|        0.82|        1.18|
# +----+-----+-----------+------------+------------+
# only showing top 5 rows

# %%
juros_relatorio.printSchema()
# Out:
# root
#  |-- ano: string (nullable = true)
#  |-- Meses: long (nullable = false)
#  |-- Valor médio: string (nullable = true)
#  |-- Valor minimo: float (nullable = true)
#  |-- Valor maximo: float (nullable = true)

# %% [markdown]
# ### <a name="questao203"> Questão 3. Salvar no hdfs:///user/<nome>/relatorioAnual com compressão zlib e formato orc </a>
#
# [voltar ao ínicio](#inicio)

# %%
juros_relatorio.write.orc("/user/tatiana/relatorioAnual", compression="zlib")

# %%
# !hdfs dfs -ls /user/tatiana/relatorioAnual
# Out:
# Found 35 items
# -rw-r--r--   2 root supergroup          0 2022-11-15 19:10 /user/tatiana/relatorioAnual/_SUCCESS
# -rw-r--r--   2 root supergroup        580 2022-11-15 19:09 /user/tatiana/relatorioAnual/part-00000-9da7af86-adf3-408d-99ce-43738d020d27-c000.zlib.orc
# -rw-r--r--   2 root supergroup        580 2022-11-15 19:09 /user/tatiana/relatorioAnual/part-00001-9da7af86-adf3-408d-99ce-43738d020d27-c000.zlib.orc
# -rw-r--r--   2 root supergroup        583 2022-11-15 19:09 /user/tatiana/relatorioAnual/part-00002-9da7af86-adf3-408d-99ce-43738d020d27-c000.zlib.orc
# -rw-r--r--   2 root supergroup        570 2022-11-15 19:09 /user/tatiana/relatorioAnual/part-00003-9da7af86-adf3-408d-99ce-43738d020d27-c000.zlib.orc
# -rw-r--r--   2 root supergroup        581 2022-11-15 19:09 /user/tatiana/relatorioAnual/part-00004-9da7af86-adf3-408d-99ce-43738d020d27-c000.zlib.orc
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
#     IMPORTANTE.
#     Vá na aba “Kernel” e aperte “Shutdown” para encerrar a sessão.
# </div>
